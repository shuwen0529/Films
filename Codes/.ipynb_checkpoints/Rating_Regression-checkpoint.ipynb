# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
# import statsmodels.api as sm
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import linregress
import math

import locale
locale.setlocale( locale.LC_ALL, "en_US.UTF-8")
# Out:
# 'en_US.UTF-8'

# %%
#Import cleanup data
movies = pd.read_csv("../Resources/US_movies_cleanup.csv", encoding ="ISO-8859-1")
movies.drop(columns = ["Unnamed: 0"], inplace=True)

### Drop all NaN based on Box Office
movies.dropna(subset=["Box Office"], how='all', inplace = True)
movies.head()
# Out:
#                                         Title Runtime (mins)  Year  \
# 1                    The Amazing Spider-Man 2        142 min  2014
# 4                          Back to the Future        116 min  1985
# 8                               Jurassic Park        127 min  1993
# 9                               The Lion King         88 min  1994
# 16  Star Wars: Episode I - The Phantom Menace        136 min  1999
#
#    Release Date                                         Genre  IMDb Rating  \
# 1   02 May 2014                     Action, Adventure, Sci-Fi          6.6
# 4   03 Jul 1985                     Adventure, Comedy, Sci-Fi          8.5
# 8   11 Jun 1993                   Adventure, Sci-Fi, Thriller          8.1
# 9   24 Jun 1994  Animation, Adventure, Drama, Family, Musical          8.5
# 16  19 May 1999            Action, Adventure, Fantasy, Sci-Fi          6.5
#
#    Num Votes Rotten Tomatoes Rating  Metascore    Box Office  Rated  \
# 1    388,759                    52%       53.0  $183,277,573  PG-13
# 4    938,445                    96%       87.0    $2,925,880     PG
# 8    784,720                    91%       68.0   $45,299,680  PG-13
# 9    838,220                    93%       83.0   $94,240,635      G
# 16   655,666                    54%       51.0  $431,000,000     PG
#
#                 Production                   Director  \
# 1            Sony Pictures                  Marc Webb
# 4       Universal Pictures            Robert Zemeckis
# 8   Universal City Studios           Steven Spielberg
# 9              Buena Vista  Roger Allers, Rob Minkoff
# 16        20th Century Fox               George Lucas
#
#                                                 Actor
# 1   Andrew Garfield, Emma Stone, Jamie Foxx, Dane ...
# 4   Michael J. Fox, Christopher Lloyd, Lea Thompso...
# 8   Sam Neill, Laura Dern, Jeff Goldblum, Richard ...
# 9   Rowan Atkinson, Matthew Broderick, Niketa Cala...
# 16  Liam Neeson, Ewan McGregor, Natalie Portman, J...

# %%
### Get Box Office and three ratings to list
BoxOffice = movies["Box Office"].tolist() 
BoxOffice_num = [locale.atof(BoxOffice[l].strip("$")) for l in range(len(BoxOffice))]
BoxOffice_million = [l/1e6 for l in BoxOffice_num] #Convert to million

IMDb_rating= movies["IMDb Rating"].tolist()
# RT_rating = movies["Rotten Tomatoes Rating"].tolist()
RT_rating = movies["Rotten Tomatoes Rating"].str.rstrip('%').astype('float')
RT_rating = RT_rating.tolist()

Metascore = movies["Metascore"].tolist()
# Out:
# [53.0,
#  87.0,
#  68.0,
#  83.0,
#  51.0,
#  64.0,
#  64.0,
#  92.0,
#  87.0,
#  48.0,
#  90.0,
#  94.0,
#  63.0,
#  66.0,
#  70.0,
#  85.0,
#  66.0,
#  62.0,
#  80.0,
#  61.0,
#  84.0,
#  79.0,
#  58.0,
#  71.0,
#  32.0,
#  73.0,
#  69.0,
#  82.0,
#  51.0,
#  88.0,
#  40.0,
#  73.0,
#  49.0,
#  83.0,
#  72.0,
#  30.0,
#  74.0,
#  74.0,
#  57.0,
#  66.0,
#  60.0,
#  63.0,
#  49.0,
#  92.0,
#  78.0,
#  66.0,
#  87.0,
#  59.0,
#  45.0,
#  65.0,
#  71.0,
#  62.0,
#  53.0,
#  69.0,
#  66.0,
#  49.0,
#  69.0,
#  41.0,
#  61.0,
#  69.0,
#  72.0,
#  50.0,
#  55.0,
#  78.0,
#  55.0,
#  81.0,
#  60.0,
#  68.0,
#  51.0,
#  76.0,
#  50.0,
#  40.0,
#  58.0,
#  47.0,
#  50.0,
#  51.0,
#  64.0,
#  58.0,
#  79.0,
#  84.0,
#  72.0,
#  40.0,
#  51.0,
#  86.0,
#  58.0,
#  36.0,
#  48.0,
#  64.0,
#  31.0,
#  57.0,
#  59.0,
#  66.0,
#  53.0,
#  81.0,
#  57.0,
#  45.0,
#  62.0,
#  31.0,
#  59.0,
#  43.0,
#  55.0,
#  72.0,
#  51.0,
#  44.0,
#  28.0,
#  61.0,
#  75.0,
#  63.0,
#  44.0,
#  64.0,
#  76.0,
#  57.0,
#  41.0,
#  68.0,
#  41.0,
#  55.0,
#  20.0,
#  63.0,
#  54.0,
#  51.0,
#  66.0,
#  55.0,
#  65.0,
#  76.0,
#  37.0,
#  61.0,
#  61.0,
#  33.0,
#  62.0,
#  67.0,
#  25.0,
#  54.0,
#  72.0,
#  50.0,
#  30.0,
#  41.0,
#  57.0,
#  nan,
#  73.0,
#  57.0,
#  63.0,
#  41.0,
#  65.0,
#  60.0,
#  62.0,
#  57.0,
#  11.0,
#  49.0,
#  40.0,
#  61.0,
#  45.0,
#  57.0,
#  nan,
#  48.0,
#  26.0,
#  68.0,
#  19.0,
#  50.0,
#  39.0,
#  66.0,
#  35.0,
#  28.0,
#  49.0,
#  37.0,
#  18.0,
#  23.0,
#  41.0,
#  51.0,
#  82.0,
#  65.0,
#  55.0,
#  78.0,
#  49.0,
#  60.0,
#  73.0,
#  96.0,
#  54.0,
#  68.0,
#  62.0,
#  63.0,
#  58.0,
#  55.0,
#  82.0,
#  64.0,
#  76.0,
#  69.0,
#  75.0,
#  81.0,
#  73.0,
#  98.0,
#  72.0,
#  66.0,
#  58.0,
#  85.0,
#  69.0,
#  91.0,
#  96.0,
#  76.0,
#  93.0,
#  35.0,
#  72.0,
#  61.0,
#  53.0,
#  61.0,
#  51.0,
#  64.0,
#  81.0,
#  78.0,
#  34.0,
#  49.0,
#  35.0,
#  56.0,
#  57.0,
#  47.0,
#  53.0,
#  79.0,
#  53.0,
#  39.0,
#  51.0,
#  45.0,
#  65.0,
#  65.0,
#  64.0,
#  47.0,
#  53.0,
#  65.0,
#  74.0,
#  47.0,
#  37.0,
#  57.0,
#  39.0,
#  50.0,
#  39.0,
#  44.0,
#  57.0,
#  36.0,
#  57.0,
#  63.0,
#  68.0,
#  52.0,
#  74.0,
#  33.0,
#  72.0,
#  70.0,
#  84.0,
#  67.0,
#  46.0,
#  56.0,
#  48.0,
#  85.0,
#  58.0,
#  42.0,
#  30.0,
#  45.0,
#  nan,
#  69.0,
#  38.0,
#  51.0,
#  58.0,
#  37.0,
#  64.0,
#  67.0,
#  31.0,
#  49.0,
#  48.0,
#  46.0,
#  60.0,
#  47.0,
#  72.0,
#  66.0,
#  44.0,
#  39.0,
#  52.0,
#  16.0,
#  53.0,
#  36.0,
#  37.0,
#  54.0,
#  84.0,
#  58.0,
#  65.0,
#  53.0,
#  62.0,
#  61.0,
#  52.0,
#  49.0,
#  49.0,
#  43.0,
#  86.0,
#  52.0,
#  56.0,
#  45.0,
#  53.0,
#  60.0,
#  53.0,
#  72.0,
#  62.0,
#  67.0,
#  46.0,
#  94.0,
#  80.0,
#  65.0,
#  68.0,
#  76.0,
#  31.0,
#  35.0,
#  39.0,
#  46.0,
#  34.0,
#  42.0,
#  35.0,
#  42.0,
#  52.0,
#  57.0,
#  90.0,
#  69.0,
#  58.0,
#  74.0,
#  84.0,
#  77.0,
#  68.0,
#  63.0,
#  80.0,
#  73.0,
#  89.0,
#  54.0,
#  82.0,
#  68.0,
#  46.0,
#  47.0,
#  84.0,
#  73.0,
#  30.0,
#  71.0,
#  86.0,
#  83.0,
#  57.0,
#  66.0,
#  72.0,
#  33.0,
#  40.0,
#  50.0,
#  74.0,
#  73.0,
#  45.0,
#  76.0,
#  53.0,
#  40.0,
#  31.0,
#  64.0,
#  71.0,
#  81.0,
#  65.0,
#  58.0,
#  50.0,
#  59.0,
#  78.0,
#  49.0,
#  73.0,
#  36.0,
#  48.0,
#  41.0,
#  23.0,
#  42.0,
#  61.0,
#  46.0,
#  20.0,
#  63.0,
#  51.0,
#  58.0,
#  69.0,
#  44.0,
#  39.0,
#  65.0,
#  52.0,
#  67.0,
#  29.0,
#  56.0,
#  31.0,
#  45.0,
#  46.0,
#  44.0,
#  75.0,
#  65.0,
#  59.0,
#  72.0,
#  40.0,
#  22.0,
#  74.0,
#  36.0,
#  41.0,
#  39.0,
#  46.0,
#  40.0,
#  45.0,
#  73.0,
#  58.0,
#  39.0,
#  62.0,
#  81.0,
#  38.0,
#  67.0,
#  48.0,
#  nan,
#  36.0,
#  73.0,
#  85.0,
#  62.0,
#  90.0,
#  64.0,
#  67.0,
#  84.0,
#  61.0,
#  74.0,
#  62.0,
#  94.0,
#  60.0,
#  68.0,
#  35.0,
#  51.0,
#  48.0,
#  32.0,
#  50.0,
#  61.0,
#  48.0,
#  56.0,
#  60.0,
#  33.0,
#  57.0,
#  38.0,
#  52.0,
#  54.0,
#  64.0,
#  32.0,
#  38.0,
#  59.0,
#  47.0,
#  62.0,
#  47.0,
#  58.0,
#  46.0,
#  75.0,
#  41.0,
#  33.0,
#  50.0,
#  34.0,
#  71.0,
#  57.0,
#  46.0,
#  33.0,
#  80.0,
#  68.0,
#  78.0,
#  38.0,
#  74.0,
#  37.0,
#  72.0,
#  nan,
#  62.0,
#  83.0,
#  64.0,
#  39.0,
#  46.0,
#  68.0,
#  48.0,
#  57.0,
#  67.0,
#  40.0,
#  43.0,
#  54.0,
#  78.0,
#  65.0,
#  57.0,
#  60.0,
#  66.0,
#  27.0,
#  33.0,
#  65.0,
#  42.0,
#  54.0,
#  56.0,
#  51.0,
#  42.0,
#  28.0,
#  79.0,
#  36.0,
#  53.0,
#  56.0,
#  44.0,
#  63.0,
#  27.0,
#  60.0,
#  53.0,
#  37.0,
#  46.0,
#  41.0,
#  49.0,
#  41.0,
#  30.0,
#  49.0,
#  18.0,
#  64.0,
#  50.0,
#  39.0,
#  49.0,
#  34.0,
#  49.0,
#  73.0,
#  56.0,
#  81.0,
#  36.0,
#  69.0,
#  24.0,
#  58.0,
#  66.0,
#  nan,
#  65.0,
#  64.0,
#  55.0,
#  48.0,
#  60.0,
#  71.0,
#  68.0,
#  61.0,
#  66.0,
#  80.0,
#  65.0,
#  49.0,
#  70.0,
#  72.0,
#  83.0,
#  59.0,
#  57.0,
#  52.0,
#  47.0,
#  82.0,
#  30.0,
#  70.0,
#  63.0,
#  86.0,
#  62.0,
#  52.0,
#  62.0,
#  73.0,
#  35.0,
#  59.0,
#  51.0,
#  46.0,
#  30.0,
#  56.0,
#  45.0,
#  66.0,
#  64.0,
#  72.0,
#  39.0,
#  47.0,
#  33.0,
#  35.0,
#  55.0,
#  63.0,
#  48.0,
#  30.0,
#  37.0,
#  62.0,
#  47.0,
#  52.0,
#  67.0,
#  71.0,
#  36.0,
#  59.0,
#  48.0,
#  64.0,
#  76.0,
#  59.0,
#  42.0,
#  17.0,
#  68.0,
#  35.0,
#  35.0,
#  61.0,
#  82.0,
#  42.0,
#  58.0,
#  45.0,
#  71.0,
#  63.0,
#  62.0,
#  43.0,
#  34.0,
#  61.0,
#  31.0,
#  54.0,
#  29.0,
#  80.0,
#  83.0,
#  85.0,
#  60.0,
#  47.0,
#  52.0,
#  64.0,
#  45.0,
#  43.0,
#  83.0,
#  34.0,
#  71.0,
#  61.0,
#  63.0,
#  86.0,
#  32.0,
#  79.0,
#  50.0,
#  35.0,
#  59.0,
#  60.0,
#  50.0,
#  23.0,
#  46.0,
#  61.0,
#  18.0,
#  51.0,
#  54.0,
#  93.0,
#  31.0,
#  71.0,
#  41.0,
#  nan,
#  40.0,
#  61.0,
#  64.0,
#  75.0,
#  44.0,
#  79.0,
#  28.0,
#  54.0,
#  27.0,
#  24.0,
#  40.0,
#  66.0,
#  55.0,
#  68.0,
#  90.0,
#  73.0,
#  58.0,
#  75.0,
#  40.0,
#  52.0,
#  52.0,
#  46.0,
#  49.0,
#  73.0,
#  40.0,
#  28.0,
#  33.0,
#  43.0,
#  74.0,
#  76.0,
#  52.0,
#  65.0,
#  72.0,
#  45.0,
#  43.0,
#  42.0,
#  56.0,
#  41.0,
#  81.0,
#  43.0,
#  38.0,
#  29.0,
#  38.0,
#  70.0,
#  61.0,
#  48.0,
#  44.0,
#  44.0,
#  41.0,
#  48.0,
#  83.0,
#  53.0,
#  81.0,
#  45.0,
#  47.0,
#  30.0,
#  89.0,
#  55.0,
#  58.0,
#  18.0,
#  43.0,
#  77.0,
#  53.0,
#  54.0,
#  62.0,
#  82.0,
#  51.0,
#  77.0,
#  56.0,
#  45.0,
#  48.0,
#  41.0,
#  44.0,
#  80.0,
#  50.0,
#  26.0,
#  69.0,
#  15.0,
#  51.0,
#  57.0,
#  47.0,
#  53.0,
#  31.0,
#  64.0,
#  55.0,
#  35.0,
#  47.0,
#  51.0,
#  36.0,
#  76.0,
#  24.0,
#  39.0,
#  41.0,
#  34.0,
#  nan,
#  52.0,
#  42.0,
#  55.0,
#  44.0,
#  57.0,
#  58.0,
#  58.0,
#  58.0,
#  22.0,
#  31.0,
#  55.0,
#  44.0,
#  56.0,
#  42.0,
#  77.0,
#  33.0,
#  56.0,
#  21.0,
#  33.0,
#  53.0,
#  44.0,
#  43.0,
#  32.0,
#  26.0,
#  45.0,
#  25.0,
#  63.0,
#  65.0,
#  46.0,
#  55.0,
#  53.0,
#  69.0,
#  53.0,
#  35.0,
#  26.0,
#  80.0,
#  26.0,
#  47.0,
#  68.0,
#  96.0,
#  55.0,
#  43.0,
#  57.0,
#  67.0,
#  54.0,
#  50.0,
#  57.0,
#  38.0,
#  37.0,
#  85.0,
#  37.0,
#  55.0,
#  69.0,
#  45.0,
#  37.0,
#  81.0,
#  61.0,
#  48.0,
#  83.0,
#  85.0,
#  63.0,
#  56.0,
#  47.0,
#  33.0,
#  75.0,
#  83.0,
#  24.0,
#  62.0,
#  60.0,
#  70.0,
#  31.0,
#  56.0,
#  59.0,
#  48.0,
#  19.0,
#  66.0,
#  44.0,
#  60.0,
#  49.0,
#  47.0,
#  94.0,
#  38.0,
#  34.0,
#  48.0,
#  64.0,
#  53.0,
#  45.0,
#  40.0,
#  46.0,
#  19.0,
#  74.0,
#  53.0,
#  45.0,
#  65.0,
#  68.0,
#  39.0,
#  63.0,
#  39.0,
#  64.0,
#  45.0,
#  25.0,
#  47.0,
#  47.0,
#  61.0,
#  49.0,
#  64.0,
#  63.0,
#  34.0,
#  29.0,
#  15.0,
#  62.0,
#  40.0,
#  41.0,
#  37.0,
#  55.0,
#  17.0,
#  38.0,
#  41.0,
#  34.0,
#  32.0,
#  33.0,
#  34.0,
#  63.0,
#  30.0,
#  34.0,
#  43.0,
#  25.0,
#  55.0,
#  51.0,
#  63.0,
#  33.0,
#  53.0,
#  66.0,
#  43.0,
#  36.0,
#  41.0,
#  43.0,
#  38.0,
#  23.0,
#  42.0,
#  28.0,
#  24.0,
#  24.0,
#  64.0,
#  45.0,
#  61.0,
#  54.0,
#  31.0,
#  nan,
#  53.0,
#  58.0,
#  33.0,
#  69.0,
#  20.0,
#  58.0,
#  45.0,
#  75.0,
#  60.0,
#  78.0,
#  28.0,
#  36.0,
#  65.0,
#  45.0,
#  50.0,
#  nan,
#  65.0,
#  38.0,
#  79.0,
#  77.0,
#  64.0,
#  72.0,
#  82.0,
#  44.0,
#  86.0,
#  88.0,
#  70.0,
#  88.0,
#  83.0,
#  88.0,
#  24.0,
#  47.0,
#  47.0,
#  54.0,
#  20.0,
#  52.0,
#  63.0,
#  30.0,
#  39.0,
#  45.0,
#  42.0,
#  48.0,
#  37.0,
#  52.0,
#  52.0,
#  45.0,
#  28.0,
#  33.0,
#  76.0,
#  38.0,
#  48.0,
#  78.0,
#  36.0,
#  82.0,
#  40.0,
#  34.0,
#  71.0,
#  53.0,
#  35.0,
#  47.0,
#  62.0,
#  67.0,
#  34.0,
#  49.0,
#  45.0,
#  65.0,
#  41.0,
#  29.0,
#  52.0,
#  59.0,
#  49.0,
#  41.0,
#  48.0,
#  69.0,
#  55.0,
#  68.0,
#  47.0,
#  29.0,
#  52.0,
#  56.0,
#  65.0,
#  67.0,
#  44.0,
#  46.0,
#  37.0,
#  25.0,
#  27.0,
#  45.0,
#  59.0,
#  27.0,
#  74.0,
#  47.0,
#  32.0,
#  45.0,
#  58.0,
#  68.0,
#  35.0,
#  30.0,
#  20.0,
#  63.0,
#  37.0,
#  30.0,
#  60.0,
#  38.0,
#  54.0,
#  45.0,
#  30.0,
#  31.0,
#  39.0,
#  32.0,
#  51.0,
#  86.0,
#  47.0,
#  55.0,
#  49.0,
#  39.0,
#  68.0,
#  45.0,
#  51.0,
#  33.0,
#  24.0,
#  35.0,
#  56.0,
#  49.0,
#  76.0,
#  54.0,
#  32.0,
#  30.0,
#  60.0,
#  42.0,
#  ...]

# %%
### Get Linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(BoxOffice, IMDb_rating)
intercept

# %%
### Start plotting 
fig, ax = plt.subplots(figsize=(6, 5))
plt.scatter(RT_rating, BoxOffice, s=1, color='b', alpha=0.5)

plt.show()

# %%
stats.linregress(BoxOffice, IMDb_rating)

# %%
type(float(BoxOffice[0]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-b46442bcc0e0> in <module>
# ----> 1 type(float(BoxOffice[0]))
#
# ValueError: could not convert string to float: '$183,277,573'
